# %% [markdown]
# # Practice Exercise – Model Training and Evaluation

# %% [markdown]
# # Problem 1: Spam email classification
#
# In this example, you will work on classifying emails as spam or not spam.
#
# You will use the [Spambase Data Set](https://archive.ics.uci.edu/ml/datasets/Spambase) from the University of California, Irvine (UCI) Machine Learning Repository.
#
# __Source information:__
#
# Creators:
# Mark Hopkins, Erik Reeber, George Forman, Jaap Suermondt, Hewlett-Packard Labs, 1501 Page Mill Rd., Palo Alto, CA 94304
#
# Donor:
# George Forman gforman@hpl.hp.com 650-857-7835
#
# ----------------------------------------------------------------------------
#
# The data has 57 attributes and 1 target. They are described below.
# - 48 continuous real [0,100] attributes of type word_freq_WORD
# = percentage of words in the e-mail that match WORD,
# i.e. 100 * (number of times the WORD appears in the e-mail) /
# total number of words in e-mail.  A "word" in this case is any
# string of alphanumeric characters bounded by non-alphanumeric
# characters or end-of-string.
#
# - 6 continuous real [0,100] attributes of type char_freq_CHAR
# = percentage of characters in the e-mail that match CHAR,
# i.e. 100 * (number of CHAR occurrences) / total characters in e-mail
#
# - 1 continuous real [1,...] attribute of type capital_run_length_average
# = average length of uninterrupted sequences of capital letters
#
# - 1 continuous integer [1,...] attribute of type capital_run_length_longest
# = length of longest uninterrupted sequence of capital letters
#
# - 1 continuous integer [1,...] attribute of type capital_run_length_total
# = sum of length of uninterrupted sequences of capital letters
# = total number of capital letters in the e-mail
#
# - 1 nominal {0,1} class attribute of type spam
# = denotes whether the e-mail was considered spam (1) or not (0), i.e. unsolicited commercial e-mail.

# %% [markdown]
# ## 1. Getting the data

# %%
import subprocess
import os

# Check whether the file is already in the desired path or if it needs to be downloaded
# File downloaded from source : https://archive.ics.uci.edu/ml/machine-learning-databases/spambase/spambase.data

base_path = '/home/ec2-user/SageMaker/data/'
file_path = 'spambase.data'

if not os.path.isfile(base_path + file_path):
    subprocess.run(['mkdir', '-p', base_path])
    subprocess.run(['aws', 's3', 'cp', 
                    's3://aws-tc-largeobjects/ILT-TF-200-MLDWTS/lab3/', 
                    base_path,'--recursive'])
else:
    print('File already downloaded!')

# %%
import csv
import numpy as np

data = []

f = open('/home/ec2-user/SageMaker/data/spambase.data')
reader = csv.reader(f)
next(reader, None)
for row in reader:
    data.append(row)
f.close()

# %% [markdown]
# Write the data into a DataFrame for easier visualization and analysis. Also, add the attribute names, which are from the "spambase.names" file in the dataset package.

# %%
import pandas as pd

df = pd.DataFrame(data=np.array(data).astype(np.float), columns=["word_freq_make",
            "word_freq_address",
            "word_freq_all",
            "word_freq_3d",
            "word_freq_our",
            "word_freq_over",
            "word_freq_remove",
            "word_freq_internet",
            "word_freq_order",
            "word_freq_mail",
            "word_freq_receive",
            "word_freq_will",
            "word_freq_people",
            "word_freq_report",
            "word_freq_addresses",
            "word_freq_free",
            "word_freq_business",
            "word_freq_email",
            "word_freq_you",
            "word_freq_credit",
            "word_freq_your",
            "word_freq_font",
            "word_freq_000",
            "word_freq_money",
            "word_freq_hp",
            "word_freq_hpl",
            "word_freq_george",
            "word_freq_650",
            "word_freq_lab",
            "word_freq_labs",
            "word_freq_telnet",
            "word_freq_857",
            "word_freq_data",
            "word_freq_415",
            "word_freq_85",
            "word_freq_technology",
            "word_freq_1999",
            "word_freq_parts",
            "word_freq_pm",
            "word_freq_direct",
            "word_freq_cs",
            "word_freq_meeting",
            "word_freq_original",
            "word_freq_project",
            "word_freq_re",
            "word_freq_edu",
            "word_freq_table",
            "word_freq_conference",
            "char_freq_;",
            "char_freq_(",
            "char_freq_[",
            "char_freq_!",
            "char_freq_$",
            "char_freq_#",
            "capital_run_length_average",
            "capital_run_length_longest",
            "capital_run_length_total",
            "target"]
            )

# %% [markdown]
# Look at the shape of the data. There are 58 columns (including the target) as expected.

# %%
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.21               0.28           0.50           0.0
# 1            0.06               0.00           0.71           0.0
# 2            0.00               0.00           0.00           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.14            0.28              0.21                0.07
# 1           1.23            0.19              0.19                0.12
# 2           0.63            0.00              0.31                0.63
# 3           0.63            0.00              0.31                0.63
# 4           1.85            0.00              0.00                1.85
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.94  ...         0.00        0.132
# 1             0.64            0.25  ...         0.01        0.143
# 2             0.31            0.63  ...         0.00        0.137
# 3             0.31            0.63  ...         0.00        0.135
# 4             0.00            0.00  ...         0.00        0.223
#
#    char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0          0.0        0.372        0.180        0.048
# 1          0.0        0.276        0.184        0.010
# 2          0.0        0.137        0.000        0.000
# 3          0.0        0.135        0.000        0.000
# 4          0.0        0.000        0.000        0.000
#
#    capital_run_length_average  capital_run_length_longest  \
# 0                       5.114                       101.0
# 1                       9.821                       485.0
# 2                       3.537                        40.0
# 3                       3.537                        40.0
# 4                       3.000                        15.0
#
#    capital_run_length_total  target
# 0                    1028.0     1.0
# 1                    2259.0     1.0
# 2                     191.0     1.0
# 3                     191.0     1.0
# 4                      54.0     1.0
#
# [5 rows x 58 columns]

# %% [markdown]
# The `df.describe()` function presents a statistical summary of the features.

# %%
df.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     4600.000000        4600.000000    4600.000000   4600.000000
# mean         0.104576           0.212922       0.280578      0.065439
# std          0.305387           1.290700       0.504170      1.395303
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.420000      0.000000
# max          4.540000          14.280000       5.100000     42.810000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    4600.000000     4600.000000       4600.000000         4600.000000
# mean        0.312222        0.095922          0.114233            0.105317
# std         0.672586        0.273850          0.391480            0.401112
# min         0.000000        0.000000          0.000000            0.000000
# 25%         0.000000        0.000000          0.000000            0.000000
# 50%         0.000000        0.000000          0.000000            0.000000
# 75%         0.382500        0.000000          0.000000            0.000000
# max        10.000000        5.880000          7.270000           11.110000
#
#        word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# count      4600.000000     4600.000000  ...  4600.000000  4600.000000
# mean          0.090087        0.239465  ...     0.038583     0.139061
# std           0.278643        0.644816  ...     0.243497     0.270377
# min           0.000000        0.000000  ...     0.000000     0.000000
# 25%           0.000000        0.000000  ...     0.000000     0.000000
# 50%           0.000000        0.000000  ...     0.000000     0.065000
# 75%           0.000000        0.160000  ...     0.000000     0.188000
# max           5.260000       18.180000  ...     4.385000     9.752000
#
#        char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# count  4600.000000  4600.000000  4600.000000  4600.000000
# mean      0.016980     0.268960     0.075827     0.044248
# std       0.109406     0.815726     0.245906     0.429388
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.314250     0.052000     0.000000
# max       4.081000    32.478000     6.003000    19.829000
#
#        capital_run_length_average  capital_run_length_longest  \
# count                 4600.000000                 4600.000000
# mean                     5.191827                   52.170870
# std                     31.732891                  194.912453
# min                      1.000000                    1.000000
# 25%                      1.588000                    6.000000
# 50%                      2.275500                   15.000000
# 75%                      3.705250                   43.000000
# max                   1102.500000                 9989.000000
#
#        capital_run_length_total       target
# count               4600.000000  4600.000000
# mean                 283.290435     0.393913
# std                  606.413764     0.488669
# min                    1.000000     0.000000
# 25%                   35.000000     0.000000
# 50%                   95.000000     0.000000
# 75%                  265.250000     1.000000
# max                15841.000000     1.000000
#
# [8 rows x 58 columns]

# %% [markdown]
# ## 2. Training the model
#
# In this section, you will do the following:
#
# - Split the dataset into training, validation, and test subsets
# - Use the Amazon SageMaker linear learner algorithm to train the model

# %% [markdown]
# > ### Question 1 - Train-test-validation split
# >
# > An important part of training a machine learning model is splitting the data into training, validation, and test subsets. You will use the `train_test_split()` function from the `sklearn` library ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)).
#
# >Look at this example:
# >
# > `train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)`
# >
# > This function splits input feature `X` and target `y` pairs by a given ratio (test_size). This specific example splits the data into training (80%) and test (20%) subsets.
# >
# > Use this function __twice__ to split the data into __training (80%)__, __validation (10%)__, and __test (10%)__ subsets.

# %%
from sklearn.model_selection import train_test_split

# Get the feature values until the target column (not included)
X = df.values[:, :-1].astype(np.float32)

# Get the target column
y = df.values[:, -1].astype(np.float32)

# Get 80% of the data for training; the remaining 20% will be for validation and test
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)

# Split the remaining 20% of data as 10% test and 10% validation
test_features, val_features, test_labels, val_labels = train_test_split(test_features, test_labels, test_size=0.5)

print(f"Length of train_features is: {train_features.shape}")
print(f"Length of train_labels is: {train_labels.shape}")
print(f"Length of val_features is: {val_features.shape}")
print(f"Length of val_labels is: {val_labels.shape}")
print(f"Length of test_features is: {test_features.shape}")
print(f"Length of test_labels is: {test_labels.shape}")
# Out:
# Length of train_features is: (3680, 57)
# Length of train_labels is: (3680,)
# Length of val_features is: (460, 57)
# Length of val_labels is: (460,)
# Length of test_features is: (460, 57)
# Length of test_labels is: (460,)

# %% [markdown]
# Now, call the Amazon SageMaker `LinearLearner()` algorithm. This example uses an `ml.m4.xlarge` instance for training. `predictor_type` is set to __'binary_classifier'__ because there are two classes: "spam" and "not spam".

# %%
import sagemaker

# Call the LinearLearner estimator object
binary_estimator = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                               instance_count=1,
                                               instance_type='ml.m4.xlarge',
                                               predictor_type='binary_classifier')

# %% [markdown]
# Use the `record_set()` function of the binary_estimator to set the training, validation, and test parts of the estimator.

# %%
train_records = binary_estimator.record_set(train_features, train_labels, channel='train')
val_records = binary_estimator.record_set(val_features, val_labels, channel='validation')
test_records = binary_estimator.record_set(test_features, test_labels, channel='test')

# %% [markdown]
# The `fit()` function applies a distributed version of the Stochastic Gradient Descent (SGD) algorithm, and we are sending the data to it.

# %%
binary_estimator.fit([train_records, val_records, test_records])
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2020-11-23 03:31:47 Starting - Starting the training job...
# 2020-11-23 03:31:49 Starting - Launching requested ML instances......
# 2020-11-23 03:33:04 Starting - Preparing the instances for training......
# 2020-11-23 03:34:18 Downloading - Downloading input data
# 2020-11-23 03:34:18 Training - Downloading the training image.....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/23/2020 03:34:55 INFO 140251379935040] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/23/2020 03:34:55 INFO 140251379935040] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'57', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier'}
# [11/23/2020 03:34:55 INFO 140251379935040] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'57', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/23/2020 03:34:55 WARNING 140251379935040] Loggers have already been setup.
# Process 1 is a worker.
# [11/23/2020 03:34:55 INFO 140251379935040] Using default worker.
# [11/23/2020 03:34:55 INFO 140251379935040] Checkpoint loading and saving are disabled.
# [2020-11-23 03:34:55.743] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-11-23 03:34:55.746] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-11-23 03:34:55.767] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 27, "num_examples": 1, "num_bytes": 276000}
# [11/23/2020 03:34:55 INFO 140251379935040] Create Store: local
# [2020-11-23 03:34:55.803] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 36, "num_examples": 4, "num_bytes": 1015680}
# [11/23/2020 03:34:55 INFO 140251379935040] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f8e727db1d0>
# [11/23/2020 03:34:55 INFO 140251379935040] Scaling model computed with parameters:
#  {'stdev_weight':
# [2.8371921e-01 1.4429818e+00 5.1488954e-01 1.5956421e+00 6.7999589e-01
#  2.7899918e-01 3.9916027e-01 3.6274374e-01 2.7873555e-01 6.7849827e-01
#  2.0432995e-01 8.4129745e-01 3.0212337e-01 2.8580517e-01 2.4501440e-01
#  8.0230767e-01 4.6500340e-01 5.1551819e-01 1.7838000e+00 4.2547813e-01
#  1.2041270e+00 1.0185713e+00 3.3093411e-01 4.5199922e-01 1.6829307e+00
#  9.5807284e-01 3.1352422e+00 5.6419569e-01 6.5551060e-01 4.7454873e-01
#  3.8444728e-01 3.6320451e-01 5.9699833e-01 3.6402804e-01 4.5861652e-01
#  4.1279536e-01 4.3992871e-01 2.2122459e-01 3.9746609e-01 3.8160956e-01
#  3.4661296e-01 7.2743493e-01 2.1322820e-01 6.4123297e-01 1.0437298e+00
#  8.6973464e-01 8.2725979e-02 3.2760236e-01 2.2458859e-01 2.3106560e-01
#  1.1814883e-01 9.1439617e-01 2.2713050e-01 4.2538273e-01 3.6210621e+01
#  1.3620258e+02 5.1277338e+02]
# <NDArray 57 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [9.85700041e-02 2.41643339e-01 2.81259984e-01 8.42066631e-02
#  3.17170024e-01 9.68066752e-02 1.16033338e-01 1.03650004e-01
#  9.12533402e-02 2.37420022e-01 5.92433363e-02 5.40050030e-01
#  9.31933373e-02 5.29333353e-02 4.58233356e-02 2.41543338e-01
#  1.44046664e-01 1.81750014e-01 1.65939009e+00 7.86466748e-02
#  8.05856705e-01 1.16270006e-01 1.00740001e-01 9.66666788e-02
#  5.56710005e-01 2.79423356e-01 7.08886683e-01 1.27900004e-01
#  1.09780006e-01 1.09690011e-01 6.67600036e-02 5.42900041e-02
#  1.01183333e-01 5.49733341e-02 1.03210002e-01 1.04473338e-01
#  1.38476670e-01 1.44766672e-02 7.32366741e-02 7.22866729e-02
#  4.01300006e-02 1.26550004e-01 4.43133339e-02 7.84000009e-02
#  3.10220003e-01 1.72406673e-01 6.26999978e-03 3.34033333e-02
#  3.59426662e-02 1.39467999e-01 1.75193325e-02 2.70160019e-01
#  7.41409957e-02 4.28593382e-02 5.49369144e+00 5.04260025e+01
#  2.64249329e+02]
# <NDArray 57 @cpu(0)>}
# [11/23/2020 03:34:55 INFO 140251379935040] nvidia-smi took: 0.0252168178558 secs to identify 0 gpus
# [11/23/2020 03:34:55 INFO 140251379935040] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Total Records Seen": {"count": 1, "max": 4680, "sum": 4680.0, "min": 4680}, "Max Records Seen Between Resets": {"count": 1, "max": 3680, "sum": 3680.0, "min": 3680}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1606102495.915871, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1606102495.915826}
#
# [2020-11-23 03:34:56.044] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 127, "num_examples": 4, "num_bytes": 1015680}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6662242838541667, "sum": 0.6662242838541667, "min": 0.6662242838541667}}, "EndTime": 1606102496.044507, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.044385}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6856481323242187, "sum": 0.6856481323242187, "min": 0.6856481323242187}}, "EndTime": 1606102496.044615, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.044592}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7328765462239584, "sum": 0.7328765462239584, "min": 0.7328765462239584}}, "EndTime": 1606102496.044682, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.044664}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7313724772135417, "sum": 0.7313724772135417, "min": 0.7313724772135417}}, "EndTime": 1606102496.044748, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.044729}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.488283935546875, "sum": 0.488283935546875, "min": 0.488283935546875}}, "EndTime": 1606102496.044806, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.044795}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.479915283203125, "sum": 0.479915283203125, "min": 0.479915283203125}}, "EndTime": 1606102496.044851, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.044834}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.47969161987304687, "sum": 0.47969161987304687, "min": 0.47969161987304687}}, "EndTime": 1606102496.044918, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.0449}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5138824259440105, "sum": 0.5138824259440105, "min": 0.5138824259440105}}, "EndTime": 1606102496.044987, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.044968}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6894984334309896, "sum": 0.6894984334309896, "min": 0.6894984334309896}}, "EndTime": 1606102496.045058, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.04504}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.703758544921875, "sum": 0.703758544921875, "min": 0.703758544921875}}, "EndTime": 1606102496.04513, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045111}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6707867228190104, "sum": 0.6707867228190104, "min": 0.6707867228190104}}, "EndTime": 1606102496.0452, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045181}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6852904663085938, "sum": 0.6852904663085938, "min": 0.6852904663085938}}, "EndTime": 1606102496.045268, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045251}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.48704596964518226, "sum": 0.48704596964518226, "min": 0.48704596964518226}}, "EndTime": 1606102496.045327, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.04531}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.46720560709635417, "sum": 0.46720560709635417, "min": 0.46720560709635417}}, "EndTime": 1606102496.045393, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045375}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.505564188639323, "sum": 0.505564188639323, "min": 0.505564188639323}}, "EndTime": 1606102496.045467, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045447}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5127234293619791, "sum": 0.5127234293619791, "min": 0.5127234293619791}}, "EndTime": 1606102496.045537, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045517}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6431759440104167, "sum": 0.6431759440104167, "min": 0.6431759440104167}}, "EndTime": 1606102496.045602, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045583}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6798634236653646, "sum": 0.6798634236653646, "min": 0.6798634236653646}}, "EndTime": 1606102496.045669, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.04565}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7169429117838542, "sum": 0.7169429117838542, "min": 0.7169429117838542}}, "EndTime": 1606102496.045737, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045717}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7505156656901042, "sum": 0.7505156656901042, "min": 0.7505156656901042}}, "EndTime": 1606102496.045802, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045784}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5315311177571614, "sum": 0.5315311177571614, "min": 0.5315311177571614}}, "EndTime": 1606102496.045866, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.04585}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5349874471028646, "sum": 0.5349874471028646, "min": 0.5349874471028646}}, "EndTime": 1606102496.045931, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045912}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5321904703776041, "sum": 0.5321904703776041, "min": 0.5321904703776041}}, "EndTime": 1606102496.046006, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.045987}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5226177571614583, "sum": 0.5226177571614583, "min": 0.5226177571614583}}, "EndTime": 1606102496.046073, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.046054}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7285402018229167, "sum": 0.7285402018229167, "min": 0.7285402018229167}}, "EndTime": 1606102496.04614, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.04612}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.697822998046875, "sum": 0.697822998046875, "min": 0.697822998046875}}, "EndTime": 1606102496.046207, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.046188}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6770077718098958, "sum": 0.6770077718098958, "min": 0.6770077718098958}}, "EndTime": 1606102496.046275, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.046256}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6716123657226563, "sum": 0.6716123657226563, "min": 0.6716123657226563}}, "EndTime": 1606102496.046342, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.046323}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.69754541015625, "sum": 0.69754541015625, "min": 0.69754541015625}}, "EndTime": 1606102496.046409, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.04639}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.710198974609375, "sum": 0.710198974609375, "min": 0.710198974609375}}, "EndTime": 1606102496.046482, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.046463}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6729807332356771, "sum": 0.6729807332356771, "min": 0.6729807332356771}}, "EndTime": 1606102496.046587, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.046567}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.74110888671875, "sum": 0.74110888671875, "min": 0.74110888671875}}, "EndTime": 1606102496.046657, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.046638}
#
# [11/23/2020 03:34:56 INFO 140251379935040] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.666224283854
# [2020-11-23 03:34:56.070] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 0, "duration": 326, "num_examples": 1, "num_bytes": 126960}
# [2020-11-23 03:34:56.235] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 2, "duration": 164, "num_examples": 1, "num_bytes": 126960}
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6194276229194973, "sum": 0.6194276229194973, "min": 0.6194276229194973}}, "EndTime": 1606102496.520184, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520058}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6252113010572351, "sum": 0.6252113010572351, "min": 0.6252113010572351}}, "EndTime": 1606102496.520317, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520293}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6826283330502717, "sum": 0.6826283330502717, "min": 0.6826283330502717}}, "EndTime": 1606102496.520387, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520369}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6629638671875, "sum": 0.6629638671875, "min": 0.6629638671875}}, "EndTime": 1606102496.520462, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520444}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.30957535453464674, "sum": 0.30957535453464674, "min": 0.30957535453464674}}, "EndTime": 1606102496.520529, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520512}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3096600408139436, "sum": 0.3096600408139436, "min": 0.3096600408139436}}, "EndTime": 1606102496.520593, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520576}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3103738536005435, "sum": 0.3103738536005435, "min": 0.3103738536005435}}, "EndTime": 1606102496.520653, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520638}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3203531679899796, "sum": 0.3203531679899796, "min": 0.3203531679899796}}, "EndTime": 1606102496.520715, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520698}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6392031462296196, "sum": 0.6392031462296196, "min": 0.6392031462296196}}, "EndTime": 1606102496.520774, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520759}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6533103611158289, "sum": 0.6533103611158289, "min": 0.6533103611158289}}, "EndTime": 1606102496.520834, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520818}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6118339206861413, "sum": 0.6118339206861413, "min": 0.6118339206861413}}, "EndTime": 1606102496.520893, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520877}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6356878529424252, "sum": 0.6356878529424252, "min": 0.6356878529424252}}, "EndTime": 1606102496.520952, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520937}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.30773239135742186, "sum": 0.30773239135742186, "min": 0.30773239135742186}}, "EndTime": 1606102496.521011, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.520996}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.30945892333984376, "sum": 0.30945892333984376, "min": 0.30945892333984376}}, "EndTime": 1606102496.521071, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521055}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.31186553291652513, "sum": 0.31186553291652513, "min": 0.31186553291652513}}, "EndTime": 1606102496.52113, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521114}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3135074449622113, "sum": 0.3135074449622113, "min": 0.3135074449622113}}, "EndTime": 1606102496.521188, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521173}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6075805000636889, "sum": 0.6075805000636889, "min": 0.6075805000636889}}, "EndTime": 1606102496.521245, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.52123}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6263241311778193, "sum": 0.6263241311778193, "min": 0.6263241311778193}}, "EndTime": 1606102496.521308, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521292}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6583925993546196, "sum": 0.6583925993546196, "min": 0.6583925993546196}}, "EndTime": 1606102496.521367, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521351}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6938471255095109, "sum": 0.6938471255095109, "min": 0.6938471255095109}}, "EndTime": 1606102496.521427, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521411}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.40479779450789743, "sum": 0.40479779450789743, "min": 0.40479779450789743}}, "EndTime": 1606102496.521485, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.52147}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.39921802023182745, "sum": 0.39921802023182745, "min": 0.39921802023182745}}, "EndTime": 1606102496.521544, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521528}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.42448116800059443, "sum": 0.42448116800059443, "min": 0.42448116800059443}}, "EndTime": 1606102496.521602, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521587}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4064602064049762, "sum": 0.4064602064049762, "min": 0.4064602064049762}}, "EndTime": 1606102496.521661, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521645}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7115520311438519, "sum": 0.7115520311438519, "min": 0.7115520311438519}}, "EndTime": 1606102496.521722, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521707}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6798617819081182, "sum": 0.6798617819081182, "min": 0.6798617819081182}}, "EndTime": 1606102496.521785, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521769}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6674124676248302, "sum": 0.6674124676248302, "min": 0.6674124676248302}}, "EndTime": 1606102496.521848, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521832}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.671375440514606, "sum": 0.671375440514606, "min": 0.671375440514606}}, "EndTime": 1606102496.521908, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521893}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6746749877929688, "sum": 0.6746749877929688, "min": 0.6746749877929688}}, "EndTime": 1606102496.521965, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.521951}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6732230808423914, "sum": 0.6732230808423914, "min": 0.6732230808423914}}, "EndTime": 1606102496.522027, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.522011}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7115553482719089, "sum": 0.7115553482719089, "min": 0.7115553482719089}}, "EndTime": 1606102496.522088, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.522071}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6446278447690217, "sum": 0.6446278447690217, "min": 0.6446278447690217}}, "EndTime": 1606102496.522146, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102496.522131}
#
# [11/23/2020 03:34:56 INFO 140251379935040] #quality_metric: host=algo-1, epoch=0, validation binary_classification_cross_entropy_objective <loss>=0.619427622919
# [11/23/2020 03:34:56 INFO 140251379935040] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=sampled_accuracy, value=0.897826086957
# [11/23/2020 03:34:56 INFO 140251379935040] Epoch 0: Loss improved. Updating best model
# [11/23/2020 03:34:56 INFO 140251379935040] Saving model for epoch: 0
# [11/23/2020 03:34:56 INFO 140251379935040] Saved checkpoint to "/tmp/tmpEPFRkf/mx-mod-0000.params"
# [11/23/2020 03:34:56 INFO 140251379935040] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Records Since Last Reset": {"count": 1, "max": 3680, "sum": 3680.0, "min": 3680}, "Total Batches Seen": {"count": 1, "max": 9, "sum": 9.0, "min": 9}, "Total Records Seen": {"count": 1, "max": 8360, "sum": 8360.0, "min": 8360}, "Max Records Seen Between Resets": {"count": 1, "max": 3680, "sum": 3680.0, "min": 3680}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1606102496.532863, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606102495.916138}
#
# [11/23/2020 03:34:56 INFO 140251379935040] #throughput_metric: host=algo-1, train throughput=5965.75572814 records/second
# [2020-11-23 03:34:56.685] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 152, "num_examples": 4, "num_bytes": 1015680}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5961302286783854, "sum": 0.5961302286783854, "min": 0.5961302286783854}}, "EndTime": 1606102496.685722, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.685613}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6138877766927083, "sum": 0.6138877766927083, "min": 0.6138877766927083}}, "EndTime": 1606102496.685906, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.685883}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6554295247395834, "sum": 0.6554295247395834, "min": 0.6554295247395834}}, "EndTime": 1606102496.685987, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.685955}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6518731892903645, "sum": 0.6518731892903645, "min": 0.6518731892903645}}, "EndTime": 1606102496.686208, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.686188}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.29395855712890623, "sum": 0.29395855712890623, "min": 0.29395855712890623}}, "EndTime": 1606102496.686264, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.68625}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2945910237630208, "sum": 0.2945910237630208, "min": 0.2945910237630208}}, "EndTime": 1606102496.68632, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.686306}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2948302103678385, "sum": 0.2948302103678385, "min": 0.2948302103678385}}, "EndTime": 1606102496.686476, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.686457}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.29881727091471355, "sum": 0.29881727091471355, "min": 0.29881727091471355}}, "EndTime": 1606102496.68656, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.686542}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6190235392252604, "sum": 0.6190235392252604, "min": 0.6190235392252604}}, "EndTime": 1606102496.68672, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.686701}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.631181620279948, "sum": 0.631181620279948, "min": 0.631181620279948}}, "EndTime": 1606102496.68678, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.686764}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6022710367838542, "sum": 0.6022710367838542, "min": 0.6022710367838542}}, "EndTime": 1606102496.686837, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.686822}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6130557657877604, "sum": 0.6130557657877604, "min": 0.6130557657877604}}, "EndTime": 1606102496.687096, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.687075}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2932486267089844, "sum": 0.2932486267089844, "min": 0.2932486267089844}}, "EndTime": 1606102496.687236, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.687215}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.28863787841796873, "sum": 0.28863787841796873, "min": 0.28863787841796873}}, "EndTime": 1606102496.687297, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.687283}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.29732056681315105, "sum": 0.29732056681315105, "min": 0.29732056681315105}}, "EndTime": 1606102496.687355, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.687341}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.29614306640625, "sum": 0.29614306640625, "min": 0.29614306640625}}, "EndTime": 1606102496.687516, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.687498}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5865256958007813, "sum": 0.5865256958007813, "min": 0.5865256958007813}}, "EndTime": 1606102496.687578, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.687561}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6178343912760417, "sum": 0.6178343912760417, "min": 0.6178343912760417}}, "EndTime": 1606102496.687785, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.687761}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.64148291015625, "sum": 0.64148291015625, "min": 0.64148291015625}}, "EndTime": 1606102496.687931, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.687908}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6774467569986979, "sum": 0.6774467569986979, "min": 0.6774467569986979}}, "EndTime": 1606102496.688101, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.688077}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4651532897949219, "sum": 0.4651532897949219, "min": 0.4651532897949219}}, "EndTime": 1606102496.688176, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.688157}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4517755126953125, "sum": 0.4517755126953125, "min": 0.4517755126953125}}, "EndTime": 1606102496.688316, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.688294}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.48208411661783857, "sum": 0.48208411661783857, "min": 0.48208411661783857}}, "EndTime": 1606102496.688445, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.688423}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4693567911783854, "sum": 0.4693567911783854, "min": 0.4693567911783854}}, "EndTime": 1606102496.688593, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.688497}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7003305257161458, "sum": 0.7003305257161458, "min": 0.7003305257161458}}, "EndTime": 1606102496.688671, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.68865}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.67919482421875, "sum": 0.67919482421875, "min": 0.67919482421875}}, "EndTime": 1606102496.688829, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.68872}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6728957112630208, "sum": 0.6728957112630208, "min": 0.6728957112630208}}, "EndTime": 1606102496.688906, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.688886}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.664231201171875, "sum": 0.664231201171875, "min": 0.664231201171875}}, "EndTime": 1606102496.68904, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.689017}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7022077840169271, "sum": 0.7022077840169271, "min": 0.7022077840169271}}, "EndTime": 1606102496.689188, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.689163}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6910577799479166, "sum": 0.6910577799479166, "min": 0.6910577799479166}}, "EndTime": 1606102496.689262, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.689243}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7556520385742187, "sum": 0.7556520385742187, "min": 0.7556520385742187}}, "EndTime": 1606102496.689403, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.689379}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6464629313151041, "sum": 0.6464629313151041, "min": 0.6464629313151041}}, "EndTime": 1606102496.689559, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102496.689535}
#
# [11/23/2020 03:34:56 INFO 140251379935040] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.596130228678
# [2020-11-23 03:34:56.875] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 5, "duration": 152, "num_examples": 1, "num_bytes": 126960}
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5595187643299933, "sum": 0.5595187643299933, "min": 0.5595187643299933}}, "EndTime": 1606102497.243386, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102497.243254}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5649875806725544, "sum": 0.5649875806725544, "min": 0.5649875806725544}}, "EndTime": 1606102497.24353, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102497.243504}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6161530867866848, "sum": 0.6161530867866848, "min": 0.6161530867866848}}, "EndTime": 1606102497.243607, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102497.243588}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5962722114894701, "sum": 0.5962722114894701, "min": 0.5962722114894701}}, "EndTime": 1606102497.243672, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102497.243655}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.29538952371348504, "sum": 0.29538952371348504, "min": 0.29538952371348504}}, "EndTime": 1606102497.243733, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102497.243715}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2965493575386379, "sum": 0.2965493575386379, "min": 0.2965493575386379}}, "EndTime": 1606102497.243803, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102497.243784}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.29488250068996263, "sum": 0.29488250068996263, "min": 0.29488250068996263}}, "EndTime": 1606102497.243873, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102497.243853}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.30519880211871603, "sum": 0.30519880211871603, "min": 0.30519880211871603}}, "EndTime": 1606102497.243941, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102497.243922}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5803621375042459, "sum": 0.5803621375042459, "min": 0.5803621375042459}}, "EndTime": 1606102497.24401, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102497.243991}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5915410580842392, "sum": 0.5915410580842392, "min": 0.5915410580842392}}, "EndTime": 1606102497.244078, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606102497.244059}
#
# ...
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.352228015402089, "sum": 0.352228015402089, "min": 0.352228015402089}}, "EndTime": 1606102503.69138, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.691363}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3385303663170856, "sum": 0.3385303663170856, "min": 0.3385303663170856}}, "EndTime": 1606102503.691442, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.691424}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.34577789306640627, "sum": 0.34577789306640627, "min": 0.34577789306640627}}, "EndTime": 1606102503.691509, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.691491}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2714997664741848, "sum": 0.2714997664741848, "min": 0.2714997664741848}}, "EndTime": 1606102503.691704, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.691681}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2726956574813179, "sum": 0.2726956574813179, "min": 0.2726956574813179}}, "EndTime": 1606102503.691775, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.691756}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.27124537592348846, "sum": 0.27124537592348846, "min": 0.27124537592348846}}, "EndTime": 1606102503.691848, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.69183}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.27162250021229617, "sum": 0.27162250021229617, "min": 0.27162250021229617}}, "EndTime": 1606102503.691918, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.691899}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4742563662321671, "sum": 0.4742563662321671, "min": 0.4742563662321671}}, "EndTime": 1606102503.691987, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.691968}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4746108345363451, "sum": 0.4746108345363451, "min": 0.4746108345363451}}, "EndTime": 1606102503.692076, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692056}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4734639706818954, "sum": 0.4734639706818954, "min": 0.4734639706818954}}, "EndTime": 1606102503.69214, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692124}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.46911229672639265, "sum": 0.46911229672639265, "min": 0.46911229672639265}}, "EndTime": 1606102503.692177, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692167}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4760653288468071, "sum": 0.4760653288468071, "min": 0.4760653288468071}}, "EndTime": 1606102503.692211, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692201}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.47740747202997624, "sum": 0.47740747202997624, "min": 0.47740747202997624}}, "EndTime": 1606102503.692263, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692246}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4784230771272079, "sum": 0.4784230771272079, "min": 0.4784230771272079}}, "EndTime": 1606102503.692329, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692311}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4824627088463825, "sum": 0.4824627088463825, "min": 0.4824627088463825}}, "EndTime": 1606102503.692396, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692378}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6603107618248981, "sum": 0.6603107618248981, "min": 0.6603107618248981}}, "EndTime": 1606102503.692471, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692451}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6574752144191576, "sum": 0.6574752144191576, "min": 0.6574752144191576}}, "EndTime": 1606102503.69254, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.69252}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6563013491423234, "sum": 0.6563013491423234, "min": 0.6563013491423234}}, "EndTime": 1606102503.692609, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692592}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.657705423106318, "sum": 0.657705423106318, "min": 0.657705423106318}}, "EndTime": 1606102503.692674, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692655}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6558729088824728, "sum": 0.6558729088824728, "min": 0.6558729088824728}}, "EndTime": 1606102503.69274, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.69272}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6589522652004076, "sum": 0.6589522652004076, "min": 0.6589522652004076}}, "EndTime": 1606102503.692807, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692788}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6524772312330163, "sum": 0.6524772312330163, "min": 0.6524772312330163}}, "EndTime": 1606102503.69288, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692861}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6615306024966032, "sum": 0.6615306024966032, "min": 0.6615306024966032}}, "EndTime": 1606102503.692941, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.692929}
#
# [11/23/2020 03:35:03 INFO 140251379935040] #quality_metric: host=algo-1, epoch=14, validation binary_classification_cross_entropy_objective <loss>=0.34078276261
# [11/23/2020 03:35:03 INFO 140251379935040] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=sampled_accuracy, value=0.915217391304
# [11/23/2020 03:35:03 INFO 140251379935040] Epoch 14: Loss improved. Updating best model
# [11/23/2020 03:35:03 INFO 140251379935040] Saving model for epoch: 14
# [11/23/2020 03:35:03 INFO 140251379935040] Saved checkpoint to "/tmp/tmptkPGBQ/mx-mod-0000.params"
# [11/23/2020 03:35:03 INFO 140251379935040] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Records Since Last Reset": {"count": 1, "max": 3680, "sum": 3680.0, "min": 3680}, "Total Batches Seen": {"count": 1, "max": 65, "sum": 65.0, "min": 65}, "Total Records Seen": {"count": 1, "max": 59880, "sum": 59880.0, "min": 59880}, "Max Records Seen Between Resets": {"count": 1, "max": 3680, "sum": 3680.0, "min": 3680}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1606102503.699924, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1606102503.248427}
#
# [11/23/2020 03:35:03 INFO 140251379935040] #throughput_metric: host=algo-1, train throughput=8148.29958849 records/second
# [11/23/2020 03:35:03 WARNING 140251379935040] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/23/2020 03:35:03 WARNING 140251379935040] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-11-23 03:35:03.836] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 47, "duration": 115, "num_examples": 1, "num_bytes": 126960}
# [11/23/2020 03:35:04 INFO 140251379935040] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=sampled_accuracy, value=0.915217391304
# [11/23/2020 03:35:04 INFO 140251379935040] Epoch 14: Loss improved. Updating best model
# [2020-11-23 03:35:04.049] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 49, "duration": 5, "num_examples": 1, "num_bytes": 126960}
# [11/23/2020 03:35:04 INFO 140251379935040] #validation_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.24835692695949388)
# [11/23/2020 03:35:04 INFO 140251379935040] #validation_score (algo-1) : ('binary_classification_accuracy', 0.9130434782608695)
# [11/23/2020 03:35:04 INFO 140251379935040] #validation_score (algo-1) : ('binary_f_1.000', 0.8863636363636364)
# [11/23/2020 03:35:04 INFO 140251379935040] #validation_score (algo-1) : ('precision', 0.8715083798882681)
# [11/23/2020 03:35:04 INFO 140251379935040] #validation_score (algo-1) : ('recall', 0.9017341040462428)
# [11/23/2020 03:35:04 INFO 140251379935040] #validation_score (algo-1) : ('roc_auc_score', 0.9660026988378886)
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, validation binary_classification_cross_entropy_objective <loss>=0.248356926959
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, validation binary_classification_accuracy <score>=0.913043478261
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, validation binary_f_1.000 <score>=0.886363636364
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, validation precision <score>=0.871508379888
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, validation recall <score>=0.901734104046
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, validation roc_auc_score <score>=0.966002698838
# [11/23/2020 03:35:04 INFO 140251379935040] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [11/23/2020 03:35:04 INFO 140251379935040] Saved checkpoint to "/tmp/tmpA4og4E/mx-mod-0000.params"
# [2020-11-23 03:35:04.056] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 8309, "num_examples": 1, "num_bytes": 126960}
# [2020-11-23 03:35:04.062] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 5, "num_examples": 1, "num_bytes": 126960}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 460, "sum": 460.0, "min": 460}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 460, "sum": 460.0, "min": 460}, "Max Records Seen Between Resets": {"count": 1, "max": 460, "sum": 460.0, "min": 460}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1606102504.064187, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1606102504.055892}
#
# [11/23/2020 03:35:04 INFO 140251379935040] #test_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.2229121498439623)
# [11/23/2020 03:35:04 INFO 140251379935040] #test_score (algo-1) : ('binary_classification_accuracy', 0.9260869565217391)
# [11/23/2020 03:35:04 INFO 140251379935040] #test_score (algo-1) : ('binary_f_1.000', 0.9119170984455959)
# [11/23/2020 03:35:04 INFO 140251379935040] #test_score (algo-1) : ('precision', 0.8934010152284264)
# [11/23/2020 03:35:04 INFO 140251379935040] #test_score (algo-1) : ('recall', 0.9312169312169312)
# [11/23/2020 03:35:04 INFO 140251379935040] #test_score (algo-1) : ('roc_auc_score', 0.9751068939260821)
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, test binary_classification_cross_entropy_objective <loss>=0.222912149844
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.926086956522
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.911917098446
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, test precision <score>=0.893401015228
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, test recall <score>=0.931216931217
# [11/23/2020 03:35:04 INFO 140251379935040] #quality_metric: host=algo-1, test roc_auc_score <score>=0.975106893926
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 8557.77883529663, "sum": 8557.77883529663, "min": 8557.77883529663}, "finalize.time": {"count": 1, "max": 353.11198234558105, "sum": 353.11198234558105, "min": 353.11198234558105}, "initialize.time": {"count": 1, "max": 166.59784317016602, "sum": 166.59784317016602, "min": 166.59784317016602}, "check_early_stopping.time": {"count": 16, "max": 1.3859272003173828, "sum": 18.094301223754883, "min": 1.004934310913086}, "setuptime": {"count": 1, "max": 28.768062591552734, "sum": 28.768062591552734, "min": 28.768062591552734}, "update.time": {"count": 15, "max": 717.0650959014893, "sum": 7725.951671600342, "min": 429.15892601013184}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1606102504.070571, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1606102495.738869}
#
#
# 2020-11-23 03:35:14 Uploading - Uploading generated training model
# 2020-11-23 03:35:14 Completed - Training job completed
# Training seconds: 73
# Billable seconds: 73

# %% [markdown]
# ## 3. Evaluating the model
#
# In this section, you will look at how the model performs with the test dataset.

# %% [markdown]
# ### Amazon SageMaker analytics
# You can use `sagemaker.analytics` to get some performance metrics. This doesn't require deploying the model. Because this is a classification problem, you can check accuracy, precision, and recall.

# %%
sagemaker.analytics.TrainingJobAnalytics(binary_estimator._current_job_name, 
                                         metric_names = ['test:binary_classification_accuracy', 
                                                         'test:precision', 
                                                         'test:recall']
                                        ).dataframe()
# Out:
#    timestamp                          metric_name     value
# 0        0.0  test:binary_classification_accuracy  0.926087
# 1        0.0                       test:precision  0.893401
# 2        0.0                          test:recall  0.931217

# %% [markdown]
# ### Deploying the model
# To deploy the model, run the following cell.
#
# **Note:** This takes some time to complete. While you are waiting, think about the answer to question 2.

# %%
binary_predictor = binary_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------------!

# %% [markdown]
# > ### Question 2 - Evaluation metric selection
# > You need to consider the business and its related restrictions when selecting the evaluation metric. In this case, spam detection requires being careful about false positives. A false positive means a good email is classified as a spam email. Because spam emails usually go to a spam folder, a user could lose important information from a false positive.
#
# >Some well-known evaluation metrics include the following:
# - Accuracy = ( TP + TN ) / ( TP + FP + FN + TN )
# - Precision = ( TP ) / ( TP + FP )
# - Recall = ( TP ) / ( TP + FN )
# >
# >In light of the provided information, which of the provided metrics do you think is the best to consider?

# %% [markdown]
# **Answer:** Precision is the choice of metric here as it accounts for the false positives. High precision means high TP and low FP.

# %% [markdown]
# Now that you have a hosted endpoint running, you can make real-time predictions from the model easily, simply by making an http POST request. First, you need to set up serializers and deserializers for passing the `test_features` NumPy arrays to the model behind the endpoint. You will also calculate the confusion matrix for the model to evaluate how it has done on the test data.

# %% [markdown]
# > ### Question 3 - Calculate metrics
# >
# > In this question, you are asked to calculate some important evaluation metrics. The accuracy calculation is used as an example. Calculate the precision and recall after accuracy.
# >
# >**Hint:** You can check your calculated values with the `sagemaker.analytics` results you got in the beginning of this section.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get predictions for each batch with size of 25
def predict_batches(predictor, features, labels):
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(features, 25)]
    # Parse protobuf responses to extract predicted labels
    extract_label = lambda x: x.label['predicted_label'].float32_tensor.values
    preds = np.concatenate([np.array([extract_label(x) for x in batch]) for batch in prediction_batches])
    preds = preds.reshape((-1,))

    # Calculate accuracy, precision, and recall
    accuracy = (preds == labels).sum() / len(labels)
    print(f'Accuracy: {accuracy}')
    
    # Calculate precision
    precision = (preds[preds == 1] == labels[preds == 1]).sum() / len(preds[preds == 1])
    print(f'Precision: {precision}')
    
    # Calculate recall
    recall = (preds[preds == 1] == labels[preds == 1]).sum() / len(labels[labels == 1])
    print(f'Recall: {recall}')
    
    confusion_matrix = pd.crosstab(index=labels, columns=np.round(preds), rownames=['True'], colnames=['predictions']).astype(int)
    plt.figure(figsize = (5,5))
    sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap="YlGnBu").set_title('Confusion Matrix')

# %% [markdown]
# Get training performance

# %%
predict_batches(binary_predictor, train_features, train_labels)
# Out:
# Accuracy: 0.9260869565217391
# Precision: 0.8916223404255319
# Recall: 0.9248275862068965

# %% [markdown]
# Get test performance

# %%
predict_batches(binary_predictor, test_features, test_labels)
# Out:
# Accuracy: 0.9260869565217391
# Precision: 0.8934010152284264
# Recall: 0.9312169312169312

# %% [markdown]
# > ### Question 4 - Compare training-test results
# > Do you see a big difference between training and test performance?

# %% [markdown]
# **Answer**: The two performances look very similar. We didn't experience overfitting here.

# %% [markdown]
# ## 4. Conclusion
# In this exercise, you developed a binary classifier using the linear learning algorithm in Amazon SageMaker. You also reviewed important concepts such as training, validation, and test splits; confusion matrices; and classification metrics. Overall, the model resulted in over 90% in the accuracy, precision, and recall metrics.

# %% [markdown]
# ----------------------------------------------------------------------------
# # Problem 2: Diabetes progression prediction (regression)
#
# For regression, you will work with a health-related dataset to predict diabetes.
#
# You will use the [Diabetes Data](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html).
#
# The __Scikit-learn__ library hosts this data as well. You will use this library to load the dataset.
#
# Fields in this dataset:
#
# Input:
# 1 - age
# 2 - sex
# 3 - bmi (Body mass index)
# 4 - bp (Blood pressure)
# 5 - s1 (Serum measurement 1)
# 6 - s2 (Serum measurement 2)
# 7 - s3 (Serum measurement 3)
# 8 - s4 (Serum measurement 4)
# 9 - s5 (Serum measurement 5)
# 10 - s6 (Serum measurement 6)
#
# Output:
# 11 - y (A quantitative measure of disease progression one year after baseline)

# %% [markdown]
# ## 1. Getting the data

# %%
import numpy as np
from sklearn.datasets import load_diabetes

diabetes = load_diabetes()
X, y = diabetes.data.astype(np.float32), diabetes.target.astype(np.float32)

print("X shape:", X.shape)
print("Y shape:", y.shape)
# Out:
# X shape: (442, 10)
# Y shape: (442,)

# %%
import pandas as pd

df = pd.DataFrame(data=np.column_stack((X, y)), 
                  columns=['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6', 'y']
                 )

# %% [markdown]
# **Note:** The features are normalized and scaled beforehand.

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6      y
# 0 -0.002592  0.019908 -0.017646  151.0
# 1 -0.039493 -0.068330 -0.092204   75.0
# 2 -0.002592  0.002864 -0.025930  141.0
# 3  0.034309  0.022692 -0.009362  206.0
# 4 -0.002592 -0.031991 -0.046641  135.0

# %%
import matplotlib.pyplot as plt
#%matplotlib inline
for col in ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']:
    plt.hist(df[col].values)
    plt.title(col + ' distribution')
    plt.xlabel(col)
    plt.ylabel('Counts')
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
#%matplotlib inline
plt.hist(y)
plt.title('Target values')
plt.xlabel('y')
plt.ylabel('Counts')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Training the model
#
# In this section, you will do the following:
#
# - Split the dataset into training, validation, and test subsets
# - Use the Amazon SageMaker linear learner algorithm to train the model

# %% [markdown]
# > ### Question 1 - Train-test-validation split
# >
# > An important part of training a machine learning model is splitting the data into training, validation, and test subsets. You will use the `train_test_split()` function from the `sklearn` library [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html).
#
# >Look at this example:
# >
# > `train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)`
# >
# > This function splits input feature `X` and target `y` pairs by a given ratio (test_size). This specific example splits the data into training (80%) and test (20%) subsets.
# >
# > Use this function __twice__ to split the data into __training (80%)__, __validation (10%)__, and __test (10%)__ subsets.

# %%
from sklearn.model_selection import train_test_split

# Get 80% of the data for training; the remaining 20% will be for validation and test
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)

# Split the remaining 20% of data as 10% test and 10% validation
test_features, val_features, test_labels, val_labels = train_test_split(test_features, test_labels, test_size=0.5)

print(f"Length of train_features is: {train_features.shape}")
print(f"Length of train_labels is: {train_labels.shape}")
print(f"Length of val_features is: {val_features.shape}")
print(f"Length of val_labels is: {val_labels.shape}")
print(f"Length of test_features is: {test_features.shape}")
print(f"Length of test_labels is: {test_labels.shape}")
# Out:
# Length of train_features is: (353, 10)
# Length of train_labels is: (353,)
# Length of val_features is: (45, 10)
# Length of val_labels is: (45,)
# Length of test_features is: (44, 10)
# Length of test_labels is: (44,)

# %% [markdown]
# Now, call the Amazon SageMaker `LinearLearner()` algorithm. This example uses an `ml.m4.xlarge` instance for training. `predictor_type` is set to __'regressor'__ because this is a regression problem.

# %%
import sagemaker

# Call the LinearLearner estimator object
regression_model = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                               instance_count=1,
                                               instance_type='ml.m4.xlarge',
                                               predictor_type='regressor')

# %% [markdown]
# Use the `record_set()` function of the binary_estimator to set the training, validation, and test parts of the estimator.

# %%
train_records = regression_model.record_set(train_features, train_labels, channel='train')
val_records = regression_model.record_set(val_features, val_labels, channel='validation')
test_records = regression_model.record_set(test_features, test_labels, channel='test')

# %% [markdown]
# The `fit()` function applies regression on this data.

# %%
regression_model.fit([train_records, val_records, test_records])
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2020-11-23 03:52:08 Starting - Starting the training job...
# 2020-11-23 03:52:10 Starting - Launching requested ML instances.........
# 2020-11-23 03:53:41 Starting - Preparing the instances for training...
# 2020-11-23 03:54:35 Downloading - Downloading input data...
# 2020-11-23 03:55:05 Training - Downloading the training image...
# 2020-11-23 03:55:32 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/23/2020 03:55:30 INFO 139929960105792] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/23/2020 03:55:30 INFO 139929960105792] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'10', u'mini_batch_size': u'353', u'predictor_type': u'regressor'}
# [11/23/2020 03:55:30 INFO 139929960105792] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'10', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'353', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/23/2020 03:55:30 WARNING 139929960105792] Loggers have already been setup.
# Process 1 is a worker.
# [11/23/2020 03:55:30 INFO 139929960105792] Using default worker.
# [11/23/2020 03:55:31 INFO 139929960105792] Checkpoint loading and saving are disabled.
# [2020-11-23 03:55:31.043] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-11-23 03:55:31.043] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-11-23 03:55:31.062] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 20, "num_examples": 1, "num_bytes": 29652}
# [11/23/2020 03:55:31 INFO 139929960105792] Create Store: local
# [2020-11-23 03:55:31.094] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 31, "num_examples": 1, "num_bytes": 29652}
# [11/23/2020 03:55:31 INFO 139929960105792] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f43a4b5e210>
# [11/23/2020 03:55:31 INFO 139929960105792] Scaling model computed with parameters:
#  {'stdev_weight':
# [0.04755907 0.04749977 0.04657046 0.04797534 0.04741991 0.04573747
#  0.04758556 0.04635797 0.04777174 0.04723803]
# <NDArray 10 @cpu(0)>, 'stdev_label':
# [75.59281]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [151.20963]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [ 3.7159785e-04 -8.9624163e-04 -5.2988413e-04 -2.3159030e-04
#   1.6170034e-04  3.8936632e-04 -7.4390881e-04  8.5943699e-05
#   8.8974790e-05  5.8853265e-04]
# <NDArray 10 @cpu(0)>}
# [11/23/2020 03:55:31 INFO 139929960105792] nvidia-smi took: 0.0252211093903 secs to identify 0 gpus
# [11/23/2020 03:55:31 INFO 139929960105792] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Total Records Seen": {"count": 1, "max": 706, "sum": 706.0, "min": 706}, "Max Records Seen Between Resets": {"count": 1, "max": 353, "sum": 353.0, "min": 353}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1606103731.206487, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1606103731.206438}
#
# [2020-11-23 03:55:31.242] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 35, "num_examples": 1, "num_bytes": 29652}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8717299507292404, "sum": 0.8717299507292404, "min": 0.8717299507292404}}, "EndTime": 1606103731.242211, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.242119}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0321608589323654, "sum": 1.0321608589323654, "min": 1.0321608589323654}}, "EndTime": 1606103731.242335, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.242294}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.812550315100478, "sum": 0.812550315100478, "min": 0.812550315100478}}, "EndTime": 1606103731.24242, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.242399}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1854763301168556, "sum": 1.1854763301168556, "min": 1.1854763301168556}}, "EndTime": 1606103731.242493, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.242473}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.045844577864952, "sum": 1.045844577864952, "min": 1.045844577864952}}, "EndTime": 1606103731.242562, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.242543}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.109649398846937, "sum": 1.109649398846937, "min": 1.109649398846937}}, "EndTime": 1606103731.242631, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.242612}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0809832780962287, "sum": 1.0809832780962287, "min": 1.0809832780962287}}, "EndTime": 1606103731.242699, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.24268}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0187331245573654, "sum": 1.0187331245573654, "min": 1.0187331245573654}}, "EndTime": 1606103731.242805, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.242784}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1447731428713703, "sum": 1.1447731428713703, "min": 1.1447731428713703}}, "EndTime": 1606103731.242871, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.242852}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0340013368946972, "sum": 1.0340013368946972, "min": 1.0340013368946972}}, "EndTime": 1606103731.24294, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.242921}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1508771772087465, "sum": 1.1508771772087465, "min": 1.1508771772087465}}, "EndTime": 1606103731.243009, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.24299}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0761155082551346, "sum": 1.0761155082551346, "min": 1.0761155082551346}}, "EndTime": 1606103731.243079, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.24306}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.076914152410145, "sum": 1.076914152410145, "min": 1.076914152410145}}, "EndTime": 1606103731.243153, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243134}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9445979737019742, "sum": 0.9445979737019742, "min": 0.9445979737019742}}, "EndTime": 1606103731.243219, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243201}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0880346541364199, "sum": 1.0880346541364199, "min": 1.0880346541364199}}, "EndTime": 1606103731.243288, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243269}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1332777850013278, "sum": 1.1332777850013278, "min": 1.1332777850013278}}, "EndTime": 1606103731.243357, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243338}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.997935524743272, "sum": 0.997935524743272, "min": 0.997935524743272}}, "EndTime": 1606103731.243426, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243407}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8388304453733623, "sum": 0.8388304453733623, "min": 0.8388304453733623}}, "EndTime": 1606103731.243489, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243471}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0830416152565068, "sum": 1.0830416152565068, "min": 1.0830416152565068}}, "EndTime": 1606103731.243556, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243537}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9333906741047716, "sum": 0.9333906741047716, "min": 0.9333906741047716}}, "EndTime": 1606103731.243616, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243599}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9893780673191838, "sum": 0.9893780673191838, "min": 0.9893780673191838}}, "EndTime": 1606103731.243684, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243665}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0756210024566217, "sum": 1.0756210024566217, "min": 1.0756210024566217}}, "EndTime": 1606103731.243738, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243722}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.010389635988403, "sum": 1.010389635988403, "min": 1.010389635988403}}, "EndTime": 1606103731.243803, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243784}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0603504559135977, "sum": 1.0603504559135977, "min": 1.0603504559135977}}, "EndTime": 1606103731.24386, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243842}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9782277396312854, "sum": 0.9782277396312854, "min": 0.9782277396312854}}, "EndTime": 1606103731.243919, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243902}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.981037345216227, "sum": 0.981037345216227, "min": 0.981037345216227}}, "EndTime": 1606103731.243983, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.243965}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.003599172273371, "sum": 1.003599172273371, "min": 1.003599172273371}}, "EndTime": 1606103731.244043, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.244025}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2631676001184047, "sum": 1.2631676001184047, "min": 1.2631676001184047}}, "EndTime": 1606103731.2441, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.244083}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0799519049884916, "sum": 1.0799519049884916, "min": 1.0799519049884916}}, "EndTime": 1606103731.244188, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.244151}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7835208363303382, "sum": 0.7835208363303382, "min": 0.7835208363303382}}, "EndTime": 1606103731.244243, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.244225}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9288509033894742, "sum": 0.9288509033894742, "min": 0.9288509033894742}}, "EndTime": 1606103731.244308, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.244289}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0016409466016731, "sum": 1.0016409466016731, "min": 1.0016409466016731}}, "EndTime": 1606103731.244367, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.244349}
#
# [11/23/2020 03:55:31 INFO 139929960105792] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.871729950729
# [2020-11-23 03:55:31.270] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 0, "duration": 227, "num_examples": 1, "num_bytes": 3780}
# [2020-11-23 03:55:31.280] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 2, "duration": 10, "num_examples": 1, "num_bytes": 3780}
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5090.492013888889, "sum": 5090.492013888889, "min": 5090.492013888889}}, "EndTime": 1606103731.28815, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.288093}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6183.308333333333, "sum": 6183.308333333333, "min": 6183.308333333333}}, "EndTime": 1606103731.28823, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.288208}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5073.964583333333, "sum": 5073.964583333333, "min": 5073.964583333333}}, "EndTime": 1606103731.28831, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.288294}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 7049.513194444445, "sum": 7049.513194444445, "min": 7049.513194444445}}, "EndTime": 1606103731.288391, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.28837}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4050.025347222222, "sum": 4050.025347222222, "min": 4050.025347222222}}, "EndTime": 1606103731.288463, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.288444}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 3930.3440972222224, "sum": 3930.3440972222224, "min": 3930.3440972222224}}, "EndTime": 1606103731.288533, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.288513}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 3876.6413194444444, "sum": 3876.6413194444444, "min": 3876.6413194444444}}, "EndTime": 1606103731.288612, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.288592}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 3879.804166666667, "sum": 3879.804166666667, "min": 3879.804166666667}}, "EndTime": 1606103731.288684, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.288664}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6688.60625, "sum": 6688.60625, "min": 6688.60625}}, "EndTime": 1606103731.28875, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.288731}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6338.419444444445, "sum": 6338.419444444445, "min": 6338.419444444445}}, "EndTime": 1606103731.28882, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.2888}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6847.2125, "sum": 6847.2125, "min": 6847.2125}}, "EndTime": 1606103731.288902, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.288879}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6315.959027777778, "sum": 6315.959027777778, "min": 6315.959027777778}}, "EndTime": 1606103731.288972, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.288952}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 3897.104513888889, "sum": 3897.104513888889, "min": 3897.104513888889}}, "EndTime": 1606103731.289042, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289023}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4056.7208333333333, "sum": 4056.7208333333333, "min": 4056.7208333333333}}, "EndTime": 1606103731.289122, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289102}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4018.3944444444446, "sum": 4018.3944444444446, "min": 4018.3944444444446}}, "EndTime": 1606103731.289203, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289181}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 3950.979861111111, "sum": 3950.979861111111, "min": 3950.979861111111}}, "EndTime": 1606103731.289271, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289252}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5919.820833333333, "sum": 5919.820833333333, "min": 5919.820833333333}}, "EndTime": 1606103731.289339, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289319}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5251.0375, "sum": 5251.0375, "min": 5251.0375}}, "EndTime": 1606103731.28941, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289391}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6602.346527777778, "sum": 6602.346527777778, "min": 6602.346527777778}}, "EndTime": 1606103731.289483, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289463}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5404.189583333334, "sum": 5404.189583333334, "min": 5404.189583333334}}, "EndTime": 1606103731.289546, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289528}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 3959.414583333333, "sum": 3959.414583333333, "min": 3959.414583333333}}, "EndTime": 1606103731.28961, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289592}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4039.9993055555556, "sum": 4039.9993055555556, "min": 4039.9993055555556}}, "EndTime": 1606103731.289675, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289657}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 3763.949652777778, "sum": 3763.949652777778, "min": 3763.949652777778}}, "EndTime": 1606103731.289751, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289731}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4049.948611111111, "sum": 4049.948611111111, "min": 4049.948611111111}}, "EndTime": 1606103731.289817, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289798}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6372.88125, "sum": 6372.88125, "min": 6372.88125}}, "EndTime": 1606103731.289885, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289865}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6037.626388888889, "sum": 6037.626388888889, "min": 6037.626388888889}}, "EndTime": 1606103731.289959, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.289939}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6360.33125, "sum": 6360.33125, "min": 6360.33125}}, "EndTime": 1606103731.290018, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.29}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 7847.665972222222, "sum": 7847.665972222222, "min": 7847.665972222222}}, "EndTime": 1606103731.290081, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.290062}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5813.944791666667, "sum": 5813.944791666667, "min": 5813.944791666667}}, "EndTime": 1606103731.290148, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.290129}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 9928.18125, "sum": 9928.18125, "min": 9928.18125}}, "EndTime": 1606103731.290218, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.290198}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 7595.304166666667, "sum": 7595.304166666667, "min": 7595.304166666667}}, "EndTime": 1606103731.290283, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.290264}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5453.857291666666, "sum": 5453.857291666666, "min": 5453.857291666666}}, "EndTime": 1606103731.290348, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.290329}
#
# [11/23/2020 03:55:31 INFO 139929960105792] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=5090.49201389
# [11/23/2020 03:55:31 INFO 139929960105792] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=3763.94965278
# [11/23/2020 03:55:31 INFO 139929960105792] Epoch 0: Loss improved. Updating best model
# [11/23/2020 03:55:31 INFO 139929960105792] Saving model for epoch: 0
# [11/23/2020 03:55:31 INFO 139929960105792] Saved checkpoint to "/tmp/tmpEWHUfZ/mx-mod-0000.params"
# [11/23/2020 03:55:31 INFO 139929960105792] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 353, "sum": 353.0, "min": 353}, "Total Batches Seen": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Total Records Seen": {"count": 1, "max": 1059, "sum": 1059.0, "min": 1059}, "Max Records Seen Between Resets": {"count": 1, "max": 353, "sum": 353.0, "min": 353}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1606103731.301624, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1606103731.206797}
#
# [11/23/2020 03:55:31 INFO 139929960105792] #throughput_metric: host=algo-1, train throughput=3716.45990457 records/second
# [2020-11-23 03:55:31.328] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 26, "num_examples": 1, "num_bytes": 29652}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8461129942291519, "sum": 0.8461129942291519, "min": 0.8461129942291519}}, "EndTime": 1606103731.328905, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.328804}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9964405092233977, "sum": 0.9964405092233977, "min": 0.9964405092233977}}, "EndTime": 1606103731.329007, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.328983}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7859056164792847, "sum": 0.7859056164792847, "min": 0.7859056164792847}}, "EndTime": 1606103731.329085, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329063}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1450970787502213, "sum": 1.1450970787502213, "min": 1.1450970787502213}}, "EndTime": 1606103731.32916, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329138}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7035274343517617, "sum": 0.7035274343517617, "min": 0.7035274343517617}}, "EndTime": 1606103731.329232, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329213}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7959852353709278, "sum": 0.7959852353709278, "min": 0.7959852353709278}}, "EndTime": 1606103731.329301, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329281}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.784545379725124, "sum": 0.784545379725124, "min": 0.784545379725124}}, "EndTime": 1606103731.329373, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329354}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7893876462077284, "sum": 0.7893876462077284, "min": 0.7893876462077284}}, "EndTime": 1606103731.329442, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329422}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1047876806502301, "sum": 1.1047876806502301, "min": 1.1047876806502301}}, "EndTime": 1606103731.329509, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.32949}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9993850664781782, "sum": 0.9993850664781782, "min": 0.9993850664781782}}, "EndTime": 1606103731.329581, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329561}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1107748317988668, "sum": 1.1107748317988668, "min": 1.1107748317988668}}, "EndTime": 1606103731.329649, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329629}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0410868614996458, "sum": 1.0410868614996458, "min": 1.0410868614996458}}, "EndTime": 1606103731.329718, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329699}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8189552890680329, "sum": 0.8189552890680329, "min": 0.8189552890680329}}, "EndTime": 1606103731.329784, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329767}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7504794631396069, "sum": 0.7504794631396069, "min": 0.7504794631396069}}, "EndTime": 1606103731.329854, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329835}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8050598490339501, "sum": 0.8050598490339501, "min": 0.8050598490339501}}, "EndTime": 1606103731.329918, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.3299}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6921649965280852, "sum": 0.6921649965280852, "min": 0.6921649965280852}}, "EndTime": 1606103731.329982, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.329963}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9641586174032843, "sum": 0.9641586174032843, "min": 0.9641586174032843}}, "EndTime": 1606103731.33005, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.33003}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8120773358655718, "sum": 0.8120773358655718, "min": 0.8120773358655718}}, "EndTime": 1606103731.330121, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.330101}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0456219638035589, "sum": 1.0456219638035589, "min": 1.0456219638035589}}, "EndTime": 1606103731.330189, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.330169}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9057903343827461, "sum": 0.9057903343827461, "min": 0.9057903343827461}}, "EndTime": 1606103731.330258, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.33024}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7352343335030099, "sum": 0.7352343335030099, "min": 0.7352343335030099}}, "EndTime": 1606103731.330325, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.330305}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7527363806878541, "sum": 0.7527363806878541, "min": 0.7527363806878541}}, "EndTime": 1606103731.330393, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.330374}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7022948440681436, "sum": 0.7022948440681436, "min": 0.7022948440681436}}, "EndTime": 1606103731.330458, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.330439}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7021985796963527, "sum": 0.7021985796963527, "min": 0.7021985796963527}}, "EndTime": 1606103731.330536, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.330516}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9799847049010711, "sum": 0.9799847049010711, "min": 0.9799847049010711}}, "EndTime": 1606103731.330611, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.330593}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9704278616324362, "sum": 0.9704278616324362, "min": 0.9704278616324362}}, "EndTime": 1606103731.330688, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.330667}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0008781800526736, "sum": 1.0008781800526736, "min": 1.0008781800526736}}, "EndTime": 1606103731.330795, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.330772}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2404355489498495, "sum": 1.2404355489498495, "min": 1.2404355489498495}}, "EndTime": 1606103731.330881, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.33086}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9798052304189536, "sum": 0.9798052304189536, "min": 0.9798052304189536}}, "EndTime": 1606103731.330964, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.330944}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.612960858655719, "sum": 1.612960858655719, "min": 1.612960858655719}}, "EndTime": 1606103731.331046, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.331025}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1969311419695026, "sum": 1.1969311419695026, "min": 1.1969311419695026}}, "EndTime": 1606103731.331127, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.331106}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9281354261187589, "sum": 0.9281354261187589, "min": 0.9281354261187589}}, "EndTime": 1606103731.331209, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.331188}
#
# [11/23/2020 03:55:31 INFO 139929960105792] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.846112994229
# [2020-11-23 03:55:31.371] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 5, "duration": 11, "num_examples": 1, "num_bytes": 3780}
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4968.194791666667, "sum": 4968.194791666667, "min": 4968.194791666667}}, "EndTime": 1606103731.380289, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.380226}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6001.9736111111115, "sum": 6001.9736111111115, "min": 6001.9736111111115}}, "EndTime": 1606103731.380376, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.380353}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4930.923611111111, "sum": 4930.923611111111, "min": 4930.923611111111}}, "EndTime": 1606103731.38045, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.380429}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6819.4875, "sum": 6819.4875, "min": 6819.4875}}, "EndTime": 1606103731.380521, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.380501}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6319.1826388888885, "sum": 6319.1826388888885, "min": 6319.1826388888885}}, "EndTime": 1606103731.380588, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.38057}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6245.954166666666, "sum": 6245.954166666666, "min": 6245.954166666666}}, "EndTime": 1606103731.380654, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.380634}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6137.395138888889, "sum": 6137.395138888889, "min": 6137.395138888889}}, "EndTime": 1606103731.38072, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.3807}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6166.225, "sum": 6166.225, "min": 6166.225}}, "EndTime": 1606103731.38079, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.38077}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6472.777083333333, "sum": 6472.777083333333, "min": 6472.777083333333}}, "EndTime": 1606103731.380863, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.380843}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6163.453472222222, "sum": 6163.453472222222, "min": 6163.453472222222}}, "EndTime": 1606103731.380932, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.380913}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6615.545833333334, "sum": 6615.545833333334, "min": 6615.545833333334}}, "EndTime": 1606103731.380996, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.380978}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6125.127777777778, "sum": 6125.127777777778, "min": 6125.127777777778}}, "EndTime": 1606103731.381071, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381051}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6063.701388888889, "sum": 6063.701388888889, "min": 6063.701388888889}}, "EndTime": 1606103731.381133, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381116}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6272.245833333333, "sum": 6272.245833333333, "min": 6272.245833333333}}, "EndTime": 1606103731.381198, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.38118}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6163.790277777778, "sum": 6163.790277777778, "min": 6163.790277777778}}, "EndTime": 1606103731.381263, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381245}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6272.472916666667, "sum": 6272.472916666667, "min": 6272.472916666667}}, "EndTime": 1606103731.381329, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381311}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5733.665625, "sum": 5733.665625, "min": 5733.665625}}, "EndTime": 1606103731.381394, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381375}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5119.320138888889, "sum": 5119.320138888889, "min": 5119.320138888889}}, "EndTime": 1606103731.381459, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381439}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6397.560416666666, "sum": 6397.560416666666, "min": 6397.560416666666}}, "EndTime": 1606103731.381525, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381506}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5306.436805555555, "sum": 5306.436805555555, "min": 5306.436805555555}}, "EndTime": 1606103731.381591, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381571}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6109.954861111111, "sum": 6109.954861111111, "min": 6109.954861111111}}, "EndTime": 1606103731.381658, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381638}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6180.842361111111, "sum": 6180.842361111111, "min": 6180.842361111111}}, "EndTime": 1606103731.381725, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381707}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5809.753819444444, "sum": 5809.753819444444, "min": 5809.753819444444}}, "EndTime": 1606103731.381793, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381773}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6148.277083333333, "sum": 6148.277083333333, "min": 6148.277083333333}}, "EndTime": 1606103731.381862, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381843}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6342.118055555556, "sum": 6342.118055555556, "min": 6342.118055555556}}, "EndTime": 1606103731.381936, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381917}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6031.4743055555555, "sum": 6031.4743055555555, "min": 6031.4743055555555}}, "EndTime": 1606103731.382005, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1606103731.381985}
#
# ...
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4958.816319444444, "sum": 4958.816319444444, "min": 4958.816319444444}}, "EndTime": 1606103731.951971, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.951957}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4155.68125, "sum": 4155.68125, "min": 4155.68125}}, "EndTime": 1606103731.952049, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952027}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5542.246527777777, "sum": 5542.246527777777, "min": 5542.246527777777}}, "EndTime": 1606103731.952131, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.95211}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5855.972916666667, "sum": 5855.972916666667, "min": 5855.972916666667}}, "EndTime": 1606103731.952204, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952184}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6061.158333333334, "sum": 6061.158333333334, "min": 6061.158333333334}}, "EndTime": 1606103731.952272, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952252}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5978.859722222222, "sum": 5978.859722222222, "min": 5978.859722222222}}, "EndTime": 1606103731.952341, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952322}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5821.501041666666, "sum": 5821.501041666666, "min": 5821.501041666666}}, "EndTime": 1606103731.952406, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952387}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5297.689583333334, "sum": 5297.689583333334, "min": 5297.689583333334}}, "EndTime": 1606103731.95248, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.95246}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5128.009375, "sum": 5128.009375, "min": 5128.009375}}, "EndTime": 1606103731.952559, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952538}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5345.425347222223, "sum": 5345.425347222223, "min": 5345.425347222223}}, "EndTime": 1606103731.952628, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952609}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5095.539583333333, "sum": 5095.539583333333, "min": 5095.539583333333}}, "EndTime": 1606103731.952681, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952669}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5887.741666666667, "sum": 5887.741666666667, "min": 5887.741666666667}}, "EndTime": 1606103731.952716, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952706}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5617.930902777778, "sum": 5617.930902777778, "min": 5617.930902777778}}, "EndTime": 1606103731.952756, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.95274}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5949.3493055555555, "sum": 5949.3493055555555, "min": 5949.3493055555555}}, "EndTime": 1606103731.952803, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952792}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5891.925, "sum": 5891.925, "min": 5891.925}}, "EndTime": 1606103731.952838, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952828}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4710.944791666667, "sum": 4710.944791666667, "min": 4710.944791666667}}, "EndTime": 1606103731.95288, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952864}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4335.714930555556, "sum": 4335.714930555556, "min": 4335.714930555556}}, "EndTime": 1606103731.952922, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952908}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5225.725347222222, "sum": 5225.725347222222, "min": 5225.725347222222}}, "EndTime": 1606103731.952998, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.952977}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4735.768055555555, "sum": 4735.768055555555, "min": 4735.768055555555}}, "EndTime": 1606103731.953069, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.953049}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4575.60625, "sum": 4575.60625, "min": 4575.60625}}, "EndTime": 1606103731.953138, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.953119}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4909.452430555555, "sum": 4909.452430555555, "min": 4909.452430555555}}, "EndTime": 1606103731.953217, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.953198}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 4956.868055555556, "sum": 4956.868055555556, "min": 4956.868055555556}}, "EndTime": 1606103731.95329, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.95327}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5120.813888888889, "sum": 5120.813888888889, "min": 5120.813888888889}}, "EndTime": 1606103731.953357, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.953338}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5972.434722222222, "sum": 5972.434722222222, "min": 5972.434722222222}}, "EndTime": 1606103731.953423, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.953405}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5986.9125, "sum": 5986.9125, "min": 5986.9125}}, "EndTime": 1606103731.953492, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.953473}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6221.577777777778, "sum": 6221.577777777778, "min": 6221.577777777778}}, "EndTime": 1606103731.953548, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.95353}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6544.066666666667, "sum": 6544.066666666667, "min": 6544.066666666667}}, "EndTime": 1606103731.953621, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.953603}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6601.377083333334, "sum": 6601.377083333334, "min": 6601.377083333334}}, "EndTime": 1606103731.953696, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.953677}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 7972.169444444445, "sum": 7972.169444444445, "min": 7972.169444444445}}, "EndTime": 1606103731.953762, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.953743}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 7248.170833333334, "sum": 7248.170833333334, "min": 7248.170833333334}}, "EndTime": 1606103731.95383, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.95381}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6249.636805555556, "sum": 6249.636805555556, "min": 6249.636805555556}}, "EndTime": 1606103731.953895, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.953876}
#
# [11/23/2020 03:55:31 INFO 139929960105792] #quality_metric: host=algo-1, epoch=7, validation mse_objective <loss>=4296.40868056
# [11/23/2020 03:55:31 INFO 139929960105792] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=mse_objective, value=4155.68125
# [11/23/2020 03:55:31 INFO 139929960105792] Saving model for epoch: 7
# [11/23/2020 03:55:31 INFO 139929960105792] Saved checkpoint to "/tmp/tmpLeRqxo/mx-mod-0000.params"
# [11/23/2020 03:55:31 INFO 139929960105792] Early stop condition met. Stopping training.
# [11/23/2020 03:55:31 INFO 139929960105792] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 353, "sum": 353.0, "min": 353}, "Total Batches Seen": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Total Records Seen": {"count": 1, "max": 3530, "sum": 3530.0, "min": 3530}, "Max Records Seen Between Resets": {"count": 1, "max": 353, "sum": 353.0, "min": 353}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1606103731.959898, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1606103731.884276}
#
# [11/23/2020 03:55:31 INFO 139929960105792] #throughput_metric: host=algo-1, train throughput=4658.84202113 records/second
# [11/23/2020 03:55:31 WARNING 139929960105792] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/23/2020 03:55:31 WARNING 139929960105792] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-11-23 03:55:31.999] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 26, "duration": 9, "num_examples": 1, "num_bytes": 3780}
# [11/23/2020 03:55:32 INFO 139929960105792] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=mse_objective, value=4155.68125
# [2020-11-23 03:55:32.010] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 28, "duration": 1, "num_examples": 1, "num_bytes": 3780}
# [11/23/2020 03:55:32 INFO 139929960105792] #validation_score (algo-1) : ('mse_objective', 3657.8177083333335)
# [11/23/2020 03:55:32 INFO 139929960105792] #validation_score (algo-1) : ('mse', 3657.8177083333335)
# [11/23/2020 03:55:32 INFO 139929960105792] #validation_score (algo-1) : ('absolute_loss', 50.162494574652776)
# [11/23/2020 03:55:32 INFO 139929960105792] #quality_metric: host=algo-1, validation mse_objective <loss>=3657.81770833
# [11/23/2020 03:55:32 INFO 139929960105792] #quality_metric: host=algo-1, validation mse <loss>=3657.81770833
# [11/23/2020 03:55:32 INFO 139929960105792] #quality_metric: host=algo-1, validation absolute_loss <loss>=50.1624945747
# [11/23/2020 03:55:32 INFO 139929960105792] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 1, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [11/23/2020 03:55:32 INFO 139929960105792] Saved checkpoint to "/tmp/tmpJq4jUg/mx-mod-0000.params"
# [2020-11-23 03:55:32.014] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 970, "num_examples": 1, "num_bytes": 3696}
# [2020-11-23 03:55:32.016] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 1, "num_examples": 1, "num_bytes": 3696}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 44, "sum": 44.0, "min": 44}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 44, "sum": 44.0, "min": 44}, "Max Records Seen Between Resets": {"count": 1, "max": 44, "sum": 44.0, "min": 44}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1606103732.016164, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1606103732.014034}
#
# [11/23/2020 03:55:32 INFO 139929960105792] #test_score (algo-1) : ('mse_objective', 4682.177911931818)
# [11/23/2020 03:55:32 INFO 139929960105792] #test_score (algo-1) : ('mse', 4682.177911931818)
# [11/23/2020 03:55:32 INFO 139929960105792] #test_score (algo-1) : ('absolute_loss', 55.43248956853693)
# [11/23/2020 03:55:32 INFO 139929960105792] #quality_metric: host=algo-1, test mse_objective <loss>=4682.17791193
# [11/23/2020 03:55:32 INFO 139929960105792] #quality_metric: host=algo-1, test mse <loss>=4682.17791193
# [11/23/2020 03:55:32 INFO 139929960105792] #quality_metric: host=algo-1, test absolute_loss <loss>=55.4324895685
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1200.843095779419, "sum": 1200.843095779419, "min": 1200.843095779419}, "finalize.time": {"count": 1, "max": 51.25689506530762, "sum": 51.25689506530762, "min": 51.25689506530762}, "initialize.time": {"count": 1, "max": 162.16492652893066, "sum": 162.16492652893066, "min": 162.16492652893066}, "check_early_stopping.time": {"count": 9, "max": 1.1608600616455078, "sum": 3.800630569458008, "min": 0.22602081298828125}, "setuptime": {"count": 1, "max": 27.843952178955078, "sum": 27.843952178955078, "min": 27.843952178955078}, "update.time": {"count": 8, "max": 145.219087600708, "sum": 725.3897190093994, "min": 72.61490821838379}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1606103732.020224, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1606103731.040672}
#
#
# 2020-11-23 03:55:40 Completed - Training job completed
# Training seconds: 65
# Billable seconds: 65

# %% [markdown]
# ## 3. Evaluating the model
#
# In this section, you will look at how your model performs with the test dataset.

# %% [markdown]
# ### Amazon SageMaker analytics
# You can use `sagemaker.analytics` to get some performance metrics. This doesn't require deploying the model. Because this is a regression problem, you can check the **mean squared error**.

# %%
sagemaker.analytics.TrainingJobAnalytics(regression_model._current_job_name, 
                                         metric_names = ['test:mse']
                                        ).dataframe()
# Out:
#    timestamp metric_name        value
# 0        0.0    test:mse  4682.177912

# %% [markdown]
# ### Deploying the model
# To deploy the model, run the following cell.
#
# **Note:** This takes some time to complete. While you are waiting, think about the answer to question 2.

# %%
regression_predictor = regression_model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ---------------!

# %% [markdown]
# >### Question 2 - Calculate mean squared error
# >
# >In this question, you will calculate the mean squared error. It is given by this equation:
# >
# >mean squared error = $\displaystyle\frac{1}{n}\sum_{t=1}^{n}(pred_t-target_t)^2$
# >
# >Calculate the mean squared error using the __preds__ and __labels__ variables and print it.

# %%
import matplotlib.pyplot as plt

# Get predictions for each batch with size of 25
def predict_regression_batches(predictor, features, labels):
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(features, 25)]
    
    # Parse protobuf responses to extract predicted labels
    extract_score = lambda x: x.label['score'].float32_tensor.values
    preds = np.concatenate([np.array([extract_score(x) for x in batch]) for batch in prediction_batches])
    preds = preds.reshape((-1,))
    
    # Calculate mean squared error
    mse = sum((preds - labels)**2) / len(preds)
    print(mse)
    
    return preds

# %% [markdown]
# Now, get the results on the training and test subsets.

# %%
train_predictions = predict_regression_batches(regression_predictor, train_features, train_labels)
# Out:
# 3376.9917414065717

# %%
test_predictions = predict_regression_batches(regression_predictor, test_features, test_labels)

# %% [markdown]
# ### Plotting results
#
# Let's look at some plots. Even though you calculated the mean squared error, it is still a good idea to examine the results visually.

# %% [markdown]
# ### Scatter plot
#
# With the scatter plot, you look at the fitted (predicted) values vs. true values. From the following plot, you can see that the predicted and true values followed a similar pattern overall.

# %%
import matplotlib.pyplot as plt
#%matplotlib inline

plt.scatter(train_predictions, train_labels, c='b', s=40, alpha=0.25, label='Training')
plt.scatter(test_predictions, test_labels, c='g', s=40, label='Test')
plt.title("Scatter plot of Fitted vs True values")
plt.ylabel("True values")
plt.xlabel("Fitted values")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Residual plot
#
# Every data point has a residual. It is the difference between the real value and the predicted value. Residuals are calculated like this:
# $e = y - \hat y$
#
# A positive residual means a higher prediction than true value, and a negative residual means a lower prediction than true value.
#
# Take a look at the residual plot from running the following block. There is a random pattern in residuals, which is good. Other patterns you might see are the U-shape or inverted U-shape patterns. These two patterns point out some non-linearity in the data, which needs to be fixed. In this case case, we don't have that problem.

# %%
import matplotlib.pyplot as plt
#%matplotlib inline

plt.scatter(train_predictions, train_predictions-train_labels, c='b', s=40, alpha=0.25, label='Training')
plt.scatter(test_predictions, test_predictions-test_labels, c='g', s=40, label='Test')
plt.hlines(y=0, xmin=0, xmax=300)
plt.title("Residual plots")
plt.ylabel("Residuals")
plt.xlabel("Fitted Values")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# >### Question 3: Residual plot assessment
# >
# >In general, looking at a residual plot allows you to realize a pattern. Patterns include:
# >- Random: This means the data is linear.
# >- U or inverse U shape: This points out some non-linearity in the data.
# >
# >What can you conclude from the residual plot?

# %% [markdown]
# **Answer**: The plot shows random residuals, meaning the data is linear.

# %% [markdown]
# ## 4. Conclusion
# In this exercise, you developed a regression model using the linear learning algorithm in Amazon SageMaker. You also covered important concepts, such as training, validation, and test splits; the mean squared error regression metric; and analysis of residual error.
